# %% [markdown]
# # Medical Insurance Cost - Machine Learning Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
train_data = pd.read_csv('medical_cost_insurance.csv')
train_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
train_data.shape
# Out:
# (1338, 7)

# %%
train_data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
train_data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
train_data.describe( include = ['O'] )
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %% [markdown]
# # Medical Insurance Charges:

# %%
plt.figure(figsize=(9,7))
sns.histplot(train_data['charges'], kde=True)
plt.title('Medical Insurance Charges', fontsize=25)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(train_data['charges'])
plt.title('Medical Insurance Charges (Box Plot)', fontsize=25)
plt.show()

# %% [markdown]
# Ages:

# %%
plt.figure(figsize=(8,5))
sns.histplot(train_data['age'], kde=True)
plt.title('Ages', fontsize=25)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(train_data['age'])
plt.title('Ages', fontsize=25)
plt.show()

# %% [markdown]
# Body Mass Index:

# %%
plt.figure(figsize=(8,5))
sns.histplot(train_data['bmi'], kde=True)
plt.title('Body Mass Index', fontsize=25)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(train_data['bmi'])
plt.title('Body Mass Index', fontsize=25)
plt.show()

# %% [markdown]
# Sex

# %%
plt.figure(figsize=(8,5))
sns.countplot(train_data['sex'])
plt.title('Sex', fontsize=25)
plt.show()

# %% [markdown]
# Children

# %%
plt.figure(figsize=(8,5))
sns.histplot(train_data['children'], kde=True)
plt.title('Children', fontsize=25)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(train_data['children'])
plt.title('Children', fontsize=25)
plt.show()

# %% [markdown]
# Smokers

# %%
plt.figure(figsize=(8,5))
sns.countplot(train_data['smoker'])
plt.title('Smokers', fontsize=25)
plt.show()

# %% [markdown]
# Regions

# %%
plt.figure(figsize=(8,5))
sns.countplot(train_data['region'])
plt.title('Regions', fontsize=25)
plt.show()

# %%
train_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
train_data = pd.get_dummies(train_data, drop_first=True)

# %%
train_data.head(2)
# Out:
#    age    bmi  children     charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.90         0  16884.9240         0           1                 0
# 1   18  33.77         1   1725.5523         1           0                 0
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0

# %%
len(train_data)
# Out:
# 1338

# %%
train_data.head(1338)
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes  \
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
#       region_northwest  region_southeast  region_southwest
# 0                    0                 0                 1
# 1                    0                 1                 0
# ...

# %%
train_data.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes',
#        'region_northwest', 'region_southeast', 'region_southwest'],
#       dtype='object')

# %%
train_data = train_data[['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes',
       'region_northwest', 'region_southeast', 'region_southwest']]
train_data.head(2)
# Out:
#    age    bmi  children     charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.90         0  16884.9240         0           1                 0
# 1   18  33.77         1   1725.5523         1           0                 0
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0

# %%
X = train_data.iloc[:, :-1]
y = train_data.iloc[:, -1]

# %%
X.head(2)
# Out:
#    age    bmi  children     charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.90         0  16884.9240         0           1                 0
# 1   18  33.77         1   1725.5523         1           0                 0
#
#    region_southeast
# 0                 0
# 1                 1

# %%
y.head(2)
# Out:
# 0    1
# 1    0
# Name: smoker_yes, dtype: uint8

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
from sklearn.linear_model import LinearRegression
LinearRegression = LinearRegression()
LinearRegression = LinearRegression.fit(X_train, y_train)

y_pred = LinearRegression.predict(X_test)

print(r2_score(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
# Out:
# 0.22339219331835447
# 0.12144768997338275

# %%
from sklearn.linear_model import Ridge
Ridge = Ridge()
Ridge = Ridge.fit(X_train, y_train)

y_pred = Ridge.predict(X_test)

print(r2_score(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
# Out:
# 0.2244342500379738
# 0.12128473078042824

# %%
from sklearn.linear_model import Lasso
Lasso = Lasso()
Lasso = Lasso.fit(X_train, y_train)

y_pred = Lasso.predict(X_test)

print(r2_score(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
# Out:
# -0.038239286391082095
# 0.1623622140892269

# %%
from sklearn.ensemble import RandomForestRegressor
RandomForestRegressor = RandomForestRegressor()
RandomForestRegressor = RandomForestRegressor.fit(X_train, y_train)

y_pred = RandomForestRegressor.predict(X_test)

print(r2_score(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
# Out:
# 0.20593069800569797
# 0.12417835820895523

# %%
import pickle
filename = 'MedicalInsuranceCost.pkl'
pickle.dump(RandomForestRegressor, open(filename, 'wb'))
